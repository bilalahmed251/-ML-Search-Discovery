# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bilalahmed251/-ML-Search-Discovery/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import pandas as pd
import numpy as np

# Load a sample dataset to get started, as the original file was not found.
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("\nFirst 5 rows of the data:")
display(df.head())
# Out:
# Rows: 17000
# Columns: 9
#
# First 5 rows of the data:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Analyze the target variable related to the decision: median_house_value
print(f"Minimum median house value: ${df['median_house_value'].min():,.2f}")
print(f"Maximum median house value: ${df['median_house_value'].max():,.2f}")
print(f"Average median house value: ${df['median_house_value'].mean():,.2f}")

# Also check for any missing values in the target variable
missing_values = df['median_house_value'].isnull().sum()
if missing_values > 0:
    print(f"Number of missing median house values: {missing_values}")
else:
    print("No missing values in median_house_value.")
# Out:
# Minimum median house value: $14,999.00
# Maximum median house value: $500,001.00
# Average median house value: $207,300.91
# No missing values in median_house_value.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Calculate 2-3 real numbers to support the lane

# 1. Number of districts (rows) in the dataset
num_districts = len(df)
print(f"Number of housing districts in the dataset: {num_districts:,}")

# 2. Average median income
# The median_income column is in units of tens of thousands of dollars
average_median_income = df['median_income'].mean()
print(f"Average median income (in tens of thousands USD): {average_median_income:.2f}")

# 3. Correlation between median_income and median_house_value
correlation = df['median_income'].corr(df['median_house_value'])
print(f"Correlation between median income and median house value: {correlation:.2f}")
# Out:
# Number of housing districts in the dataset: 17,000
# Average median income (in tens of thousands USD): 3.88
# Correlation between median income and median house value: 0.69

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# My lane is content refresh and CTR improvement. I want to investigate which visible web pages should receive higher refresh priority when they have low CTR, weak average position, or declining performance. I chose this lane because these signals can help an SEO/content team decide which pages to review first.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
