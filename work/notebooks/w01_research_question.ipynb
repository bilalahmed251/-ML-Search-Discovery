# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bilalahmed251/-ML-Search-Discovery/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane is content refresh and CTR improvement. I want to investigate which visible web pages should receive higher refresh priority when they have low CTR, weak average position, or declining performance.

# %%
import os
import pandas as pd

repo = "/content/ML-Search-Discovery"

if not os.path.exists(repo):
    # !git clone -q --depth 1 https://github.com/bilalahmed251/-ML-Search-Discovery.git {repo}

df = pd.read_csv(f"{repo}/data/raw/content_refresh_anonymized.csv" )

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.head(3))
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# 2     23643.0  ...     15000-25000  0.09          36.5             0.00
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# ...

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# My research question is: Which visible pages should be prioritized for content refresh when they have low CTR, weak average position, or declining performance? The SEO/content team will use this decision. A wrong recommendation could waste editing time or cause an important declining page to be missed.

# %%
# This cell is no longer needed as the target variable analysis for the new problem is covered in the next section.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
declining_rate = df["trend_direction"].astype(str).str.lower().eq("down").mean()

visible_low_ctr = df[
    (df["impressions_90d"] >= 100) &
    (df["ctr"] < 0.5)
]

print("Total pages:", len(df))
print("Declining rate:", round(declining_rate, 3))
print("Visible low-CTR pages:", len(visible_low_ctr))

print(
    df[df["impressions_90d"] >= 100]
    .groupby("position_tier")["ctr"]
    .mean()
    .round(4)
)
# Out:
# Total pages: 30000
# Declining rate: 0.542
# Visible low-CTR pages: 18614
# position_tier
# deep        0.0554
# page_1      0.3548
# page_3_5    0.1424
# striking    0.2558
# top_3       0.3341
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project will report observed, measured, and directional patterns for decision support.

# %%
# My lane is content refresh and CTR improvement. I want to investigate which visible web pages should receive higher refresh priority when they have low CTR, weak average position, or declining performance. I chose this lane because these signals can help an SEO/content team decide which pages to review first.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
